# %%
import cv2

imagePath = 'my_pic.jpg'
#import requests
#import matplotlib.pyplot as plt

 # Get user supplied values
#url = 'https://i.imgur.com/ExdKOOz.png'
#filename = url.split('/')[-1]
#r = requests.get(url, allow_redirects=True)
#open(filename, 'wb').write(r.content)

# Read the image
image = cv2.imread(imagePath)

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


kernel_size = (5,5)
# opencv has implementation for kernel based box blurring
blur = cv2.blur(gray,kernel_size)

#cv2.imshow("Grayscale image", gray)
#cv2.imshow("Blur image", blur)
filename = 'savedImage.jpg'


# Using cv2.imwrite() method 
# Saving the image 
cv2.imwrite(filename, blur) 

from IPython.display import Image
Image('savedImage.jpg')

# %%
![picture](https://drive.google.com/us?id=15QvqlPQKoZj3j9crKQxxy6BhXkqQjNBK)
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `https://drive.google.com/us?id=15QvqlPQKoZj3j9crKQxxy6BhXkqQjNBK'
# /bin/bash: -c: line 0: `[picture](https://drive.google.com/us?id=15QvqlPQKoZj3j9crKQxxy6BhXkqQjNBK)'

# %%
# !gdown --id 15QvqlPQKoZj3j9crKQxxy6BhXkqQjNBK
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=15QvqlPQKoZj3j9crKQxxy6BhXkqQjNBK
# To: /content/my_pic.jpg
# 100% 103k/103k [00:00<00:00, 28.7MB/s]

# %%
ls
# Out:
# ExdKOOz.png  my_pic.jpg  sample_data/  sample.png  savedImage.jpg

# %%
from IPython.display import Image
Image('savedImage.jpg')
